# %% [markdown]
# # CSCI 5922 Final Project
# ### Anya Lee

# %% [markdown]
# First, load the farm insects data. This dataset contains 1,591 relatively clean images with 15 classes (about 100 images per class)
